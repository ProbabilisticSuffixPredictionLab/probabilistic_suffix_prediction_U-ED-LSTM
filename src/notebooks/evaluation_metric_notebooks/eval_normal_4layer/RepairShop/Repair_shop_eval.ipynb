# %%
import importlib
import sys
import pickle
import numpy as np

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')
sys.path.insert(0, '../../../../../..')

# %%
import src.evaluation_metrics.conduct_evaluation
importlib.reload(src.evaluation_metrics.conduct_evaluation)

import src.evaluation_metrics.metrics
importlib.reload(src.evaluation_metrics.metrics)
# Out:
# <module 'src.evaluation_metrics.metrics' from '/home/LordKunkler/probabilistic_suffix_prediction_lab/probabilistic_suffix_prediction_dev/src/notebooks/evaluation_metric_notebooks/eval_normal_4layer/RepairShop/../../../../../src/evaluation_metrics/metrics.py'>

# %%
import src.evaluation_metrics.plots
importlib.reload(src.evaluation_metrics.plots)

output_dirs = ['../../../../../../../data/repair_shop/gn_l4/']

all_results = dict()

event_label_list = ['RECEPTION', 'ACKNOWLEDGEMENT', 'DISASSEMBLY', 'REPAIR', 'QUALITY_CONTROL',
                    'CREATE_INVOICE', 'SHIPPING', 'FINISHED']

for output_dir in output_dirs:
    evaluation_metrics = {
        'NormalizedDamerauLevenshteinMeanVar_activity' : src.evaluation_metrics.metrics.NormalizedDamerauLevenshteinDistanceMeanVar('concept:name', percentile=0.25),
        'RemainingTime_SUM_Mean_MAE_outliers' : src.evaluation_metrics.metrics.SumValueMeanMAE('event_elapsed_time', percentile=0.25, value_factor = 3600*24),
        'RemainingTime_SUM_Abs_Mean_MAE_outliers' : src.evaluation_metrics.metrics.SumAbsValueMeanMAE('event_elapsed_time', percentile=0.25, value_factor = 3600*24),
        'RemainingTime_LastEvent_Mean2_Var_seconds_outliers' : src.evaluation_metrics.metrics.LastValueMean2VarMAE('case_elapsed_time', percentile=0.25, value_factor=3600*24),
        'RemainingTime_PIT' : src.evaluation_metrics.metrics.LastValuePIT('case_elapsed_time'),
        'EventElapsed_PIT' : src.evaluation_metrics.metrics.SumValuesPIT('event_elapsed_time'),
        'SuffixCountMAE' : src.evaluation_metrics.metrics.SuffixCountMAE(percentile=0.25),

        'SumValuesInterval_50' : src.evaluation_metrics.metrics.SumValuesInterval('event_elapsed_time', percentile=0.5),
        'SumValuesInterval_75' : src.evaluation_metrics.metrics.SumValuesInterval('event_elapsed_time', percentile=0.75),
        # 'SumValuesInterval_90' : src.evaluation_metrics.metrics.SumValuesInterval('event_elapsed_time', percentile=0.90),
        'SumValuesInterval_95' : src.evaluation_metrics.metrics.SumValuesInterval('event_elapsed_time', percentile=0.95),
        # 'SumValuesInterval_99' : src.evaluation_metrics.metrics.SumValuesInterval('event_elapsed_time', percentile=0.99),

        'LastValueInterval_50' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.50),
        'LastValueInterval_75' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.75),
        # 'LastValueInterval_90' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.90),
        'LastValueInterval_95' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.95),
        # 'LastValueInterval_99' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.99),

        'SuffixCountInterval_50' : src.evaluation_metrics.metrics.SuffixCountInterval(percentile=0.50),
        'SuffixCountInterval_75' : src.evaluation_metrics.metrics.SuffixCountInterval(percentile=0.75),
        # 'SuffixCountInterval_90' : src.evaluation_metrics.metrics.SuffixCountInterval(percentile=0.90),
        'SuffixCountInterval_95' : src.evaluation_metrics.metrics.SuffixCountInterval(percentile=0.95),
        # 'SuffixCountInterval_99' : src.evaluation_metrics.metrics.SuffixCountInterval(percentile=0.99),

        # 'EventLabelCountInterval_50' : src.evaluation_metrics.metrics.EventLabelCountInterval('concept:name', event_label_list, percentile=0.50),
        # 'EventLabelCountInterval_75' : src.evaluation_metrics.metrics.EventLabelCountInterval('concept:name', event_label_list, percentile=0.75),
        # 'EventLabelCountInterval_90' : src.evaluation_metrics.metrics.EventLabelCountInterval('concept:name', event_label_list, percentile=0.90),
        # 'EventLabelCountInterval_95' : src.evaluation_metrics.metrics.EventLabelCountInterval('concept:name', event_label_list, percentile=0.95),
        # 'EventLabelCountInterval_99' : src.evaluation_metrics.metrics.EventLabelCountInterval('concept:name', event_label_list, percentile=0.99),

        # 'EventLabelCount' : src.evaluation_metrics.metrics.EventLabelCount('concept:name', 'REPAIR'),
        #'EventLabelCountACK' : src.evaluation_metrics.metrics.EventLabelCount('concept:name', 'ACKNOWLEDGEMENT'),

    }

    res_raw, c = src.evaluation_metrics.conduct_evaluation.batch_evaluate(output_dir, evaluation_metrics, num_workers=16)
    #res_raw, c = src.evaluation_metrics.conduct_evaluation.evaluate_sequentially(output_dir, evaluation_metrics)
    all_results[output_dir] = (res_raw, c)

with open("Repair_shop_eval.pkl", "wb") as file:
    pickle.dump(all_results, file)
# Out:
# Loaded: results_part_100.pkl
# Loaded: results_part_1200.pkl
# Loaded: results_part_150.pkl
# Loaded: results_part_1400.pkl
# Loaded: results_part_1500.pkl
# Loaded: results_part_1300.pkl
# Loaded: results_part_1450.pkl
# Loaded: results_part_1550.pkl
# Loaded: results_part_1150.pkl
# Loaded: results_part_1050.pkl
# Loaded: results_part_1350.pkl
# Loaded: results_part_1600.pkl
# Loaded: results_part_1250.pkl
# Loaded: results_part_050.pkl
# Loaded: results_part_1000.pkl
# Loaded: results_part_1100.pkl
# Loaded: results_part_1650.pkl
# Loaded: results_part_1850.pkl
# Loaded: results_part_1750.pkl
# Loaded: results_part_1950.pkl
# Loaded: results_part_2000.pkl
# Loaded: results_part_1700.pkl
# Loaded: results_part_1900.pkl
# Loaded: results_part_200.pklLoaded: results_part_1800.pkl
#
# Loaded: results_part_2150.pkl
# Loaded: results_part_2300.pkl
# Loaded: results_part_2250.pkl
# Loaded: results_part_2100.pkl
# Loaded: results_part_2200.pkl
# Loaded: results_part_2050.pkl
# Loaded: results_part_2350.pkl
# Loaded: results_part_2400.pkl
# Loaded: results_part_2450.pkl
# Loaded: results_part_250.pkl
# Loaded: results_part_2500.pkl
# Loaded: results_part_2550.pkl
# Loaded: results_part_2650.pkl
# Loaded: results_part_2600.pkl
# Loaded: results_part_2750.pkl
# Loaded: results_part_2700.pkl
# Loaded: results_part_2850.pkl
# Loaded: results_part_3000.pkl
# Loaded: results_part_2950.pkl
# Loaded: results_part_2900.pkl
# Loaded: results_part_2800.pkl
# Loaded: results_part_3050.pkl
# Loaded: results_part_300.pkl
# Loaded: results_part_3100.pkl
# Loaded: results_part_3150.pkl
# Loaded: results_part_3200.pkl
# Loaded: results_part_3250.pkl
# Loaded: results_part_3300.pkl
# Loaded: results_part_3350.pkl
# Loaded: results_part_3400.pkl
# Loaded: results_part_3450.pkl
# Loaded: results_part_350.pkl
# Loaded: results_part_3650.pkl
# Loaded: results_part_3500.pkl
# Loaded: results_part_3550.pkl
# Loaded: results_part_3700.pkl
# Loaded: results_part_3850.pkl
# Loaded: results_part_3750.pkl
# Loaded: results_part_3800.pkl
# Loaded: results_part_3600.pkl
# Loaded: results_part_3950.pkl
# Loaded: results_part_400.pkl
# Loaded: results_part_3900.pkl
# Loaded: results_part_4050.pkl
# Loaded: results_part_4000.pkl
# Loaded: results_part_4100.pkl
# Loaded: results_part_4150.pkl
# Loaded: results_part_4200.pkl
# Loaded: results_part_4350.pkl
# Loaded: results_part_4300.pkl
# Loaded: results_part_4250.pkl
# Loaded: results_part_450.pkl
# Loaded: results_part_4450.pkl
# Loaded: results_part_4500.pkl
# Loaded: results_part_4400.pkl
# Loaded: results_part_4650.pkl
# Loaded: results_part_4550.pkl
# Loaded: results_part_4600.pkl
# Loaded: results_part_4850.pkl
# Loaded: results_part_4750.pkl
# Loaded: results_part_4700.pkl
# Loaded: results_part_4800.pkl
# Loaded: results_part_4950.pkl
# Loaded: results_part_4900.pkl
# Loaded: results_part_500.pkl
# Loaded: results_part_5050.pkl
# Loaded: results_part_5000.pkl
# Loaded: results_part_5100.pkl
# Loaded: results_part_5150.pkl
# Loaded: results_part_5300.pkl
# Loaded: results_part_5250.pkl
# Loaded: results_part_5200.pkl
# Loaded: results_part_5350.pkl
# Loaded: results_part_5500.pkl
# Loaded: results_part_5550.pkl
# Loaded: results_part_5450.pkl
# Loaded: results_part_5600.pkl
# Loaded: results_part_550.pkl
# Loaded: results_part_5400.pkl
# Loaded: results_part_5650.pkl
# Loaded: results_part_5750.pkl
# Loaded: results_part_5700.pkl
# Loaded: results_part_5800.pkl
# Loaded: results_part_5850.pkl
# Loaded: results_part_5900.pkl
# Loaded: results_part_5950.pkl
# Loaded: results_part_600.pkl
# Loaded: results_part_6000.pkl
# Loaded: results_part_6050.pkl
# Loaded: results_part_6100.pkl
# Loaded: results_part_6150.pkl
# Loaded: results_part_6250.pkl
# Loaded: results_part_6300.pkl
# Loaded: results_part_6400.pkl
# Loaded: results_part_6350.pkl
# Loaded: results_part_6200.pkl
# Loaded: results_part_6450.pkl
# Loaded: results_part_6550.pkl
# Loaded: results_part_650.pkl
# Loaded: results_part_6500.pkl
# Loaded: results_part_6600.pkl
# Loaded: results_part_6700.pkl
# Loaded: results_part_6750.pkl
# Loaded: results_part_6650.pkl
# Loaded: results_part_6800.pkl
# Loaded: results_part_6900.pkl
# Loaded: results_part_6850.pkl
# Loaded: results_part_6950.pkl
# Loaded: results_part_700.pkl
# Loaded: results_part_7000.pkl
# Loaded: results_part_7050.pkl
# Loaded: results_part_7100.pkl
# Loaded: results_part_7200.pkl
# Loaded: results_part_7150.pkl
# Loaded: results_part_7300.pkl
# Loaded: results_part_750.pkl
# Loaded: results_part_7400.pkl
# Loaded: results_part_7450.pkl
# Loaded: results_part_7350.pkl
# Loaded: results_part_7550.pkl
# Loaded: results_part_7500.pkl
# Loaded: results_part_7250.pkl
# Loaded: results_part_7600.pkl
# Loaded: results_part_7650.pkl
# Loaded: results_part_7700.pkl
# Loaded: results_part_7800.pkl
# Loaded: results_part_7750.pkl
# Loaded: results_part_7850.pkl
# Loaded: results_part_7900.pkl
# Loaded: results_part_7950.pkl
# Loaded: results_part_800.pkl
# Loaded: results_part_8000.pkl
# Loaded: results_part_8100.pkl
# Loaded: results_part_8050.pkl
# Loaded: results_part_8200.pkl
# Loaded: results_part_8150.pkl
# Loaded: results_part_8300.pkl
# Loaded: results_part_8250.pkl
# Loaded: results_part_8350.pkl
# Loaded: results_part_8400.pkl
# Loaded: results_part_850.pkl
# Loaded: results_part_8450.pkl
# Loaded: results_part_8500.pkl
# Loaded: results_part_8550.pkl
# Loaded: results_part_8600.pkl
# Loaded: results_part_8650.pkl
# Loaded: results_part_8750.pkl
# Loaded: results_part_8800.pklLoaded: results_part_8700.pkl
#
# Loaded: results_part_8900.pkl
# Loaded: results_part_8850.pkl
# Loaded: results_part_900.pkl
# Loaded: results_part_9000.pkl
# Loaded: results_part_8950.pkl
# Loaded: results_part_9050.pkl
# Loaded: results_part_9150.pkl
# Loaded: results_part_9564.pkl
# Loaded: results_part_9200.pkl
# Loaded: results_part_9250.pkl
# Loaded: results_part_9100.pkl
# Loaded: results_part_9300.pkl
# Loaded: results_part_9350.pkl
# Loaded: results_part_9400.pkl
# Loaded: results_part_9450.pkl
# Loaded: results_part_950.pkl
# Loaded: results_part_9500.pkl
# Loaded: results_part_9550.pkl

# %%
with open("Repair_shop_eval.pkl", "rb") as file:
    all_results = pickle.load(file)

import src.evaluation_metrics.plots
importlib.reload(src.evaluation_metrics.plots)

res_raw, c = all_results['../../../../../../../evaluation_results/repair_shop/gn_l4/']
keys_to_keep = [
                ('SuffixCountMAE', 'Suffix length MAE'),
                ('NormalizedDamerauLevenshteinMeanVar_activity', 'DLS'),
                ('RemainingTime_SUM_Abs_Mean_MAE_outliers', 'Remaining time MAE (days)'),
                # ('SuffixCountInterval_50', 'SuffixCountInterval_50'),
                # ('SuffixCountInterval_75', 'SuffixCountInterval_75'),
                # ('SuffixCountInterval_90', 'SuffixCountInterval_90'),
                # ('SuffixCountInterval_95', 'SuffixCountInterval_95'),
                # ('SuffixCountInterval_99', 'SuffixCountInterval_99'),


                ('SumValuesInterval_50', 'SumValuesInterval_50'),
                ('SumValuesInterval_75', 'SumValuesInterval_75'),
                # ('SumValuesInterval_90', 'SumValuesInterval_90'),
                ('SumValuesInterval_95', 'SumValuesInterval_95'),
                # ('SumValuesInterval_99', 'SumValuesInterval_99'),

                # ('LastValueInterval_50', 'LastValueInterval_50'),
                # ('LastValueInterval_75', 'LastValueInterval_75'),
                # ('LastValueInterval_90', 'LastValueInterval_90'),
                # ('LastValueInterval_95', 'LastValueInterval_95'),
                # ('LastValueInterval_99', 'LastValueInterval_99'),
]

res = {(k, label) : res_raw[k] for k, label in keys_to_keep}
print(res_raw.keys())
print(len(res_raw.keys()))
print(len(res.keys()))
print(len(keys_to_keep))
print(res.keys())
p = src.evaluation_metrics.plots.plot_res(res, c, columns=2, caption='Repair Shop', pgf=True)#int(len(keys_to_keep)))

with open('Repair_Shop_eval.pgf', 'wb') as f:
    f.write(p)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 7
#       4 import src.evaluation_metrics.plots
#       5 importlib.reload(src.evaluation_metrics.plots)
# ----> 7 res_raw, c = all_results['../../../../../../../evaluation_results/repair_shop/gn_l4/']
#       8 keys_to_keep = [
#       9                 ('SuffixCountMAE', 'Suffix length MAE'),
#      10                 ('NormalizedDamerauLevenshteinMeanVar_activity', 'DLS'),
#    (...)     29                 # ('LastValueInterval_99', 'LastValueInterval_99'),
#      30 ]
#      32 res = {(k, label) : res_raw[k] for k, label in keys_to_keep}
#
# KeyError: '../../../../../../../evaluation_results/repair_shop/gn_l4/'

# %%
import src.evaluation_metrics.plots
importlib.reload(src.evaluation_metrics.plots)

with open('Repair_Shop_PIT_event_elapsed.pgf', 'wb') as f:
    r = src.evaluation_metrics.plots.plot_pits(res_raw['EventElapsed_PIT'], caption='Repair Shop', x_label='Sum of event processing times', pgf=True)
    f.write(r)

with open('Repair_Shop_PIT_remaining_time.pgf', 'wb') as f:
    r = src.evaluation_metrics.plots.plot_pits(res_raw['RemainingTime_PIT'], caption='Repair Shop', x_label='Last case elapsed time', pgf=True)
    f.write(r)

# %%
print('Suffix length MAE')
print(np.mean([i['mean'] for i in res_raw['SuffixCountMAE'].values()]))
print('Probabilistic suffix length MAE')
print(np.mean([i['prob'][0] for i in res_raw['SuffixCountMAE'].values()]))

print('DLS')
print(np.mean([i['mean'] for i in res_raw['NormalizedDamerauLevenshteinMeanVar_activity'].values()]))
print('Probabilistic DLS')
print(np.mean([i['prob'][0] for i in res_raw['NormalizedDamerauLevenshteinMeanVar_activity'].values()]))

print('Mean MAE sum remaining time:')
print(np.mean([i['mean'] for i in res_raw['RemainingTime_SUM_Mean_MAE_outliers'].values()]))
print('Probabilistic MAE sum remaining time:')
print(np.mean([i['prob'][0] for i in res_raw['RemainingTime_SUM_Mean_MAE_outliers'].values()]))

print('Mean MAE last event:')
print(np.mean([i['mean'] for i in res_raw['RemainingTime_LastEvent_Mean2_Var_seconds_outliers'].values()]))
print('Probabilistic MAE last event:')
print(np.mean([i['prob'][0] for i in res_raw['RemainingTime_LastEvent_Mean2_Var_seconds_outliers'].values()]))
