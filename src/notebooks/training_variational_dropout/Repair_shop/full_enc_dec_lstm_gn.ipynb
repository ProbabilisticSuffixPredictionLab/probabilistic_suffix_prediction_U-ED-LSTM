# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../encoded_data/repair_shop_5_train.pkl'
# Load the dataset using torch.load
repair_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(repair_train_dataset))  # Should output something like <class 'torch.utils.data.dataset.TensorDataset'>

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../encoded_data/repair_shop_5_val.pkl'
# Load the dataset using torch.load
repair_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(repair_val_dataset))  # Should output something like <class 'torch.utils.data.dataset.TensorDataset'>
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Repair Shop Dataset Categories, Features:

repair_all_categories = repair_train_dataset.all_categories

repair_all_categories_cat = repair_all_categories[0]
print(repair_all_categories_cat)

repair_all_categories_num = repair_all_categories[1]
print(repair_all_categories_num)

for i, cat in enumerate(repair_all_categories_cat):
     print(f"Repair Shop (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Repair Shop (5) Total Amount of Category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(repair_all_categories_num):
     print(f"Repair Shop (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Repair Shop (5) Amount Category Lables: {num[1]}")
# Out:
# [('concept:name', 9, {'ACKNOWLEDGEMENT': 1, 'CREATE_INVOICE': 2, 'DISASSEMBLY': 3, 'EOS': 4, 'QUALITY_CONTROL': 5, 'RECEPTION': 6, 'REPAIR': 7, 'SHIPPING': 8})]
# [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})]
# Repair Shop (5) Categorical feature: concept:name, Index position in categorical data list: 0
# Repair Shop (5) Total Amount of Category labels: 9
#
#
# Repair Shop (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Repair Shop (5) Amount Category Lables: 1
# Repair Shop (5) Numerical feature: event_elapsed_time, Index position in categorical data list: 1
# Repair Shop (5) Amount Category Lables: 1
# Repair Shop (5) Numerical feature: day_in_week, Index position in categorical data list: 2
# Repair Shop (5) Amount Category Lables: 1
# Repair Shop (5) Numerical feature: seconds_in_day, Index position in categorical data list: 3
# Repair Shop (5) Amount Category Lables: 1

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)

# Encoder features:
enc_feat_cat = []
enc_feat_num = []
for cat in repair_all_categories_cat:
    enc_feat_cat.append(cat[0])
for num in repair_all_categories_num:
    enc_feat_num.append(num[0])
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

# Decoder features:
dec_feat_cat = enc_feat_cat
dec_feat_num = ['case_elapsed_time', 'event_elapsed_time']
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['concept:name'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Features decoder:  [['concept:name'], ['case_elapsed_time', 'event_elapsed_time']]

# %% [markdown]
# # Model

# %%
import model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model
importlib.reload(model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model)
from model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

# Prediction decoder output sequence length
seq_len_pred = 4

# Size hidden layer
hidden_size = 128

# Number of cells
num_layers = 4

# Fixed Dropout probability 
dropout = 0.1

# Encoder Decoder model initialization
model = DropoutUncertaintyEncoderDecoderLSTM(data_set_categories=repair_all_categories,
                                             enc_feat=enc_feat,
                                             dec_feat=dec_feat,
                                             seq_len_pred=seq_len_pred,
                                             hidden_size=hidden_size,
                                             num_layers=num_layers,
                                             dropout=dropout)
# Out:
# Data set categories:  ([('concept:name', 9, {'ACKNOWLEDGEMENT': 1, 'CREATE_INVOICE': 2, 'DISASSEMBLY': 3, 'EOS': 4, 'QUALITY_CONTROL': 5, 'RECEPTION': 6, 'REPAIR': 7, 'SHIPPING': 8})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Encoder input features:  [['concept:name'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Decoder input+output features:  [['concept:name'], ['case_elapsed_time', 'event_elapsed_time']]
#
#
# Sequence length of decoder output:  4
#
#
# Cells hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.1
#
#
# Encoder number of labels for each input feature (categorical, numerical):  [[9], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input:  [[0], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(9, 5)
# )
# Total embedding feature size encoder:  5
# Total numerical feature size encoder:  4
# Input feature size encoder:  9
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [9]
# Decoder label values size for each numerical input feature:  [1, 1]
# Decoder indices of tensors in dataset used as input:  [[0], [0, 1]]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(9, 5)
# )
# Total embedding feature size decoder:  5
# Total numerical feature size decoder:  2
# Input feature size decoder:  7
# Output feature list of dicts (featue name, feature output size) of decoder:  [{'concept:name': 9}, {'case_elapsed_time': 1, 'event_elapsed_time': 1}]
# Decoder initialized!
#
# Output feature list of dicts (featue name, tensor index in dataset) of decoder:  [{'concept:name': 0}, {'case_elapsed_time': 0, 'event_elapsed_time': 1}]

# %% [markdown]
# # Loss Object Creation

# %%
import loss.losses
importlib.reload(loss.losses)
from loss.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import trainer.trainer
importlib.reload(trainer.trainer)
from trainer.trainer import Trainer
from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_Repair_shop_grad")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Start learning rate
learning_rate = 1e-4

# Optimizer and Scheduler
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=1e-5, patience=1, min_lr=1e-10)

# Epochs
num_epochs = 100

# BATCHING does not work currntly with custom implementation
batch_size = 128

# lambda for L2 (weight, bias, dropout) regularization: According to formula: 1/2N
regularization_term = 1.0/(2.0*batch_size)

# shuffle data
shuffle = True

# Teacher forcing: Smaller 0.5 more target events are used for next event prediction.
teacher_forcing_ratio = 0.8

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle,
                   "teacher_forcing_ratio":teacher_forcing_ratio,}

suffix_data_split_value = 4

# GradNorm parameter
use_gradnorm = True
gn_alpha = 1.5
gn_learning_rate = 1e-4
# gn_learning_rate =  0.025

number_tasks = len(dec_feat[0]) + len(dec_feat[1])

gradNorm = {"use_gradnorm":use_gradnorm,
            "number_tasks": number_tasks,
            "gn_alpha":gn_alpha,
            "gn_learning_rate": gn_learning_rate}

## Changed name because of good results of actual model

trainer = Trainer(device=device,
                  model=model,
                  data_train=repair_train_dataset,
                  data_val=repair_val_dataset,
                  loss_obj=loss_obj,
                  log_normal_loss_num_feature= [],
                  optimize_values=optimize_values,
                  suffix_data_split_value=suffix_data_split_value,
                  writer=writer,
                  gradnorm_values=gradNorm,
                  save_model_n_th_epoch = 1,
                  saving_path = 'repair_shop_full_grad_norm_new_4layer.pkl')

# Train the model:
train_attenuated_losses, val_losses, val_attenuated_losses = trainer.train_model()
# Out:
# Device:  cuda
# Model:  DropoutUncertaintyEncoderDecoderLSTM(
#   (embeddings_enc): ModuleList(
#     (0): Embedding(9, 5)
#   )
#   (encoder): DropoutUncertaintyLSTMEncoder(
#     (embeddings): ModuleList(
#       (0): Embedding(9, 5)
#     )
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=9, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=9, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=9, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=9, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#   )
#   (embeddings_dec): ModuleList(
#     (0): Embedding(9, 5)
#   )
#   (decoder): DropoutUncertaintyLSTMDecoder(
#     (embeddings): ModuleList(
#       (0): Embedding(9, 5)
#     )
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=7, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=7, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=7, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=7, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (output_layers): ModuleDict(
#       (concept:name_mean): Linear(in_features=128, out_features=9, bias=True)
#       (concept:name_var): Linear(in_features=128, out_features=9, bias=True)
#       (case_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (case_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (event_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# Train Dataset:  <event_log_loader.new_event_log_loader.EventLogDataset object at 0x7fc7fc3a2a50>
# Validation Dataset:  <event_log_loader.new_event_log_loader.EventLogDataset object at 0x7fc7fbd88a50>
# Loss object for method calling:  <loss.losses.Loss object at 0x7fc7fb0701a0>
# Num. feautures that follow log-normal PDF:  []
# regularization:  0.00390625
# Optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7fc7f2b59160>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
# Teacher forcing ratio:  0.8
# Use GradNorm:  True
# GradNorm alpha:  1.5
# GradNorm learning rate:  0.0001
# Initial GradNorm loss weights:  Parameter containing:
# tensor([1., 1., 1.], requires_grad=True)
# Initial loss values:  None
# GradNorm optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0
# )
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch [1/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 13.0641
# Validation: Avg Standard Validation Loss: 3.4039
# Validation: Avg Attenuated Validation Loss: 18.7373
# Validation Loss for Scheduler: 3.4039
# saving model
# Epoch [2/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 14.8005
# Validation: Avg Standard Validation Loss: 3.1833
# Validation: Avg Attenuated Validation Loss: 39.3336
# Validation Loss for Scheduler: 3.1833
# saving model
# Epoch [3/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 14.6242
# Validation: Avg Standard Validation Loss: 3.0744
# Validation: Avg Attenuated Validation Loss: 55.9723
# Validation Loss for Scheduler: 3.0744
# saving model
# Epoch [4/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 14.3622
# Validation: Avg Standard Validation Loss: 2.9513
# Validation: Avg Attenuated Validation Loss: 1.3586
# Validation Loss for Scheduler: 2.9513
# saving model
# Epoch [5/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.8317
# Validation: Avg Standard Validation Loss: 2.5267
# Validation: Avg Attenuated Validation Loss: 24.7161
# Validation Loss for Scheduler: 2.5267
# saving model
# Epoch [6/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.4851
# Validation: Avg Standard Validation Loss: 2.4260
# Validation: Avg Attenuated Validation Loss: 15.3615
# Validation Loss for Scheduler: 2.4260
# saving model
# Epoch [7/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.3135
# Validation: Avg Standard Validation Loss: 2.3194
# Validation: Avg Attenuated Validation Loss: 20.1937
# Validation Loss for Scheduler: 2.3194
# saving model
# Epoch [8/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.5353
# Validation: Avg Standard Validation Loss: 2.2962
# Validation: Avg Attenuated Validation Loss: 15.7435
# Validation Loss for Scheduler: 2.2962
# saving model
# Epoch [9/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.1298
# Validation: Avg Standard Validation Loss: 2.2245
# Validation: Avg Attenuated Validation Loss: 4.5079
# Validation Loss for Scheduler: 2.2245
# saving model
# Epoch [10/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.1870
# Validation: Avg Standard Validation Loss: 2.1975
# Validation: Avg Attenuated Validation Loss: 15.1240
# Validation Loss for Scheduler: 2.1975
# saving model
# Epoch [11/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.4040
# Validation: Avg Standard Validation Loss: 2.1247
# Validation: Avg Attenuated Validation Loss: 5.4481
# Validation Loss for Scheduler: 2.1247
# saving model
# Epoch [12/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.5309
# Validation: Avg Standard Validation Loss: 2.1194
# Validation: Avg Attenuated Validation Loss: 14.3073
# Validation Loss for Scheduler: 2.1194
# saving model
# Epoch [13/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.6461
# Validation: Avg Standard Validation Loss: 2.1750
# Validation: Avg Attenuated Validation Loss: 21.9893
# Validation Loss for Scheduler: 2.1750
# saving model
# Epoch [14/100], Learning Rate: 0.0001, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.7794
# Validation: Avg Standard Validation Loss: 2.1678
# Validation: Avg Attenuated Validation Loss: 24.9463
# Validation Loss for Scheduler: 2.1678
# saving model
# Epoch [15/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.9530
# Validation: Avg Standard Validation Loss: 2.1789
# Validation: Avg Attenuated Validation Loss: 23.3356
# Validation Loss for Scheduler: 2.1789
# saving model
# Epoch [16/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.8438
# Validation: Avg Standard Validation Loss: 2.1674
# Validation: Avg Attenuated Validation Loss: 23.9688
# Validation Loss for Scheduler: 2.1674
# saving model
# Epoch [17/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 13.1266
# Validation: Avg Standard Validation Loss: 2.1651
# Validation: Avg Attenuated Validation Loss: 24.1147
# Validation Loss for Scheduler: 2.1651
# saving model
# Epoch [18/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 13.4248
# Validation: Avg Standard Validation Loss: 2.1749
# Validation: Avg Attenuated Validation Loss: 24.9716
# Validation Loss for Scheduler: 2.1749
# saving model
# Epoch [19/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.9886
# Validation: Avg Standard Validation Loss: 2.1936
# Validation: Avg Attenuated Validation Loss: 25.1537
# Validation Loss for Scheduler: 2.1936
# saving model
# Epoch [20/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.8
# Training: Avg Attenuated Training Loss: 12.9945
# Validation: Avg Standard Validation Loss: 2.1798
# Validation: Avg Attenuated Validation Loss: 22.9756
# Validation Loss for Scheduler: 2.1798
# saving model
# Epoch [21/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 12.9102
# Validation: Avg Standard Validation Loss: 2.1527
# Validation: Avg Attenuated Validation Loss: 23.8717
# Validation Loss for Scheduler: 2.1527
# saving model
# Epoch [22/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.1363
# Validation: Avg Standard Validation Loss: 2.1770
# Validation: Avg Attenuated Validation Loss: 23.7327
# Validation Loss for Scheduler: 2.1770
# saving model
# Epoch [23/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.1088
# Validation: Avg Standard Validation Loss: 2.1660
# Validation: Avg Attenuated Validation Loss: 24.6714
# Validation Loss for Scheduler: 2.1660
# saving model
# Epoch [24/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.1653
# Validation: Avg Standard Validation Loss: 2.1641
# Validation: Avg Attenuated Validation Loss: 21.9542
# Validation Loss for Scheduler: 2.1641
# saving model
# Epoch [25/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.0499
# Validation: Avg Standard Validation Loss: 2.1597
# Validation: Avg Attenuated Validation Loss: 22.8457
# Validation Loss for Scheduler: 2.1597
# saving model
# Epoch [26/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.0034
# Validation: Avg Standard Validation Loss: 2.1842
# Validation: Avg Attenuated Validation Loss: 23.7843
# Validation Loss for Scheduler: 2.1842
# saving model
# Epoch [27/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.2490
# Validation: Avg Standard Validation Loss: 2.1642
# Validation: Avg Attenuated Validation Loss: 21.7807
# Validation Loss for Scheduler: 2.1642
# saving model
# Epoch [28/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.0308
# Validation: Avg Standard Validation Loss: 2.1528
# Validation: Avg Attenuated Validation Loss: 23.1285
# Validation Loss for Scheduler: 2.1528
# saving model
# Epoch [29/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 12.8551
# Validation: Avg Standard Validation Loss: 2.1616
# Validation: Avg Attenuated Validation Loss: 22.9259
# Validation Loss for Scheduler: 2.1616
# saving model
# Epoch [30/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.1129
# Validation: Avg Standard Validation Loss: 2.1938
# Validation: Avg Attenuated Validation Loss: 22.2871
# Validation Loss for Scheduler: 2.1938
# saving model
# Epoch [31/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 12.7501
# Validation: Avg Standard Validation Loss: 2.1534
# Validation: Avg Attenuated Validation Loss: 22.4734
# Validation Loss for Scheduler: 2.1534
# saving model
# Epoch [32/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 12.8413
# Validation: Avg Standard Validation Loss: 2.1669
# Validation: Avg Attenuated Validation Loss: 21.0117
# Validation Loss for Scheduler: 2.1669
# saving model
# Epoch [33/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.0025
# Validation: Avg Standard Validation Loss: 2.1629
# Validation: Avg Attenuated Validation Loss: 21.5332
# Validation Loss for Scheduler: 2.1629
# saving model
# Epoch [34/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 12.9811
# Validation: Avg Standard Validation Loss: 2.1717
# Validation: Avg Attenuated Validation Loss: 21.0162
# Validation Loss for Scheduler: 2.1717
# saving model
# Epoch [35/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 12.8626
# Validation: Avg Standard Validation Loss: 2.1939
# Validation: Avg Attenuated Validation Loss: 21.8673
# Validation Loss for Scheduler: 2.1939
# saving model
# Epoch [36/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 12.8500
# Validation: Avg Standard Validation Loss: 2.1606
# Validation: Avg Attenuated Validation Loss: 22.6035
# Validation Loss for Scheduler: 2.1606
# saving model
# Epoch [37/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.1370
# Validation: Avg Standard Validation Loss: 2.1561
# Validation: Avg Attenuated Validation Loss: 23.9883
# Validation Loss for Scheduler: 2.1561
# saving model
# Epoch [38/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.1900
# Validation: Avg Standard Validation Loss: 2.1787
# Validation: Avg Attenuated Validation Loss: 24.2643
# Validation Loss for Scheduler: 2.1787
# saving model
# Epoch [39/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 12.8507
# Validation: Avg Standard Validation Loss: 2.1758
# Validation: Avg Attenuated Validation Loss: 22.5180
# Validation Loss for Scheduler: 2.1758
# saving model
# Epoch [40/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.768
# Training: Avg Attenuated Training Loss: 13.0062
# Validation: Avg Standard Validation Loss: 2.1738
# Validation: Avg Attenuated Validation Loss: 22.9212
# Validation Loss for Scheduler: 2.1738
# saving model
# Epoch [41/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.0454
# Validation: Avg Standard Validation Loss: 2.1694
# Validation: Avg Attenuated Validation Loss: 21.0891
# Validation Loss for Scheduler: 2.1694
# saving model
# Epoch [42/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.1502
# Validation: Avg Standard Validation Loss: 2.1858
# Validation: Avg Attenuated Validation Loss: 22.6661
# Validation Loss for Scheduler: 2.1858
# saving model
# Epoch [43/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 12.9983
# Validation: Avg Standard Validation Loss: 2.1664
# Validation: Avg Attenuated Validation Loss: 23.7869
# Validation Loss for Scheduler: 2.1664
# saving model
# Epoch [44/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.2417
# Validation: Avg Standard Validation Loss: 2.1669
# Validation: Avg Attenuated Validation Loss: 25.2466
# Validation Loss for Scheduler: 2.1669
# saving model
# Epoch [45/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.1597
# Validation: Avg Standard Validation Loss: 2.1520
# Validation: Avg Attenuated Validation Loss: 22.2054
# Validation Loss for Scheduler: 2.1520
# saving model
# Epoch [46/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 12.9115
# Validation: Avg Standard Validation Loss: 2.1618
# Validation: Avg Attenuated Validation Loss: 22.6581
# Validation Loss for Scheduler: 2.1618
# saving model
# Epoch [47/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.1767
# Validation: Avg Standard Validation Loss: 2.1749
# Validation: Avg Attenuated Validation Loss: 20.5734
# Validation Loss for Scheduler: 2.1749
# saving model
# Epoch [48/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.3114
# Validation: Avg Standard Validation Loss: 2.1700
# Validation: Avg Attenuated Validation Loss: 22.6792
# Validation Loss for Scheduler: 2.1700
# saving model
# Epoch [49/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.2706
# Validation: Avg Standard Validation Loss: 2.1587
# Validation: Avg Attenuated Validation Loss: 23.4730
# Validation Loss for Scheduler: 2.1587
# saving model
# Epoch [50/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.0960
# Validation: Avg Standard Validation Loss: 2.1558
# Validation: Avg Attenuated Validation Loss: 21.9688
# Validation Loss for Scheduler: 2.1558
# saving model
# Epoch [51/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.0844
# Validation: Avg Standard Validation Loss: 2.1744
# Validation: Avg Attenuated Validation Loss: 24.4352
# Validation Loss for Scheduler: 2.1744
# saving model
# Epoch [52/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.1280
# Validation: Avg Standard Validation Loss: 2.1968
# Validation: Avg Attenuated Validation Loss: 22.7627
# Validation Loss for Scheduler: 2.1968
# saving model
# Epoch [53/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 12.9817
# Validation: Avg Standard Validation Loss: 2.1812
# Validation: Avg Attenuated Validation Loss: 23.1924
# Validation Loss for Scheduler: 2.1812
# saving model
# Epoch [54/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.2019
# Validation: Avg Standard Validation Loss: 2.1945
# Validation: Avg Attenuated Validation Loss: 21.0280
# Validation Loss for Scheduler: 2.1945
# saving model
# Epoch [55/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.0458
# Validation: Avg Standard Validation Loss: 2.1662
# Validation: Avg Attenuated Validation Loss: 23.5366
# Validation Loss for Scheduler: 2.1662
# saving model
# Epoch [56/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.1462
# Validation: Avg Standard Validation Loss: 2.1724
# Validation: Avg Attenuated Validation Loss: 22.9553
# Validation Loss for Scheduler: 2.1724
# saving model
# Epoch [57/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.2921
# Validation: Avg Standard Validation Loss: 2.1802
# Validation: Avg Attenuated Validation Loss: 24.0144
# Validation Loss for Scheduler: 2.1802
# saving model
# Epoch [58/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 12.9971
# Validation: Avg Standard Validation Loss: 2.1524
# Validation: Avg Attenuated Validation Loss: 24.0143
# Validation Loss for Scheduler: 2.1524
# saving model
# Epoch [59/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.1286
# Validation: Avg Standard Validation Loss: 2.1663
# Validation: Avg Attenuated Validation Loss: 22.4909
# Validation Loss for Scheduler: 2.1663
# saving model
# Epoch [60/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.73728
# Training: Avg Attenuated Training Loss: 13.1573
# Validation: Avg Standard Validation Loss: 2.1863
# Validation: Avg Attenuated Validation Loss: 24.2552
# Validation Loss for Scheduler: 2.1863
# saving model
# Epoch [61/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.0316
# Validation: Avg Standard Validation Loss: 2.1587
# Validation: Avg Attenuated Validation Loss: 21.3894
# Validation Loss for Scheduler: 2.1587
# saving model
# Epoch [62/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.3190
# Validation: Avg Standard Validation Loss: 2.1689
# Validation: Avg Attenuated Validation Loss: 24.8076
# Validation Loss for Scheduler: 2.1689
# saving model
# Epoch [63/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.1769
# Validation: Avg Standard Validation Loss: 2.1721
# Validation: Avg Attenuated Validation Loss: 23.1156
# Validation Loss for Scheduler: 2.1721
# saving model
# Epoch [64/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.0185
# Validation: Avg Standard Validation Loss: 2.1793
# Validation: Avg Attenuated Validation Loss: 23.1672
# Validation Loss for Scheduler: 2.1793
# saving model
# Epoch [65/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.1405
# Validation: Avg Standard Validation Loss: 2.1671
# Validation: Avg Attenuated Validation Loss: 24.1395
# Validation Loss for Scheduler: 2.1671
# saving model
# Epoch [66/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 12.9794
# Validation: Avg Standard Validation Loss: 2.1747
# Validation: Avg Attenuated Validation Loss: 24.1988
# Validation Loss for Scheduler: 2.1747
# saving model
# Epoch [67/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.1246
# Validation: Avg Standard Validation Loss: 2.1616
# Validation: Avg Attenuated Validation Loss: 23.7677
# Validation Loss for Scheduler: 2.1616
# saving model
# Epoch [68/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.0823
# Validation: Avg Standard Validation Loss: 2.1589
# Validation: Avg Attenuated Validation Loss: 25.0452
# Validation Loss for Scheduler: 2.1589
# saving model
# Epoch [69/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.1511
# Validation: Avg Standard Validation Loss: 2.1632
# Validation: Avg Attenuated Validation Loss: 21.5805
# Validation Loss for Scheduler: 2.1632
# saving model
# Epoch [70/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.1797
# Validation: Avg Standard Validation Loss: 2.1729
# Validation: Avg Attenuated Validation Loss: 21.9888
# Validation Loss for Scheduler: 2.1729
# saving model
# Epoch [71/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.1287
# Validation: Avg Standard Validation Loss: 2.1984
# Validation: Avg Attenuated Validation Loss: 25.0893
# Validation Loss for Scheduler: 2.1984
# saving model
# Epoch [72/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.2052
# Validation: Avg Standard Validation Loss: 2.1868
# Validation: Avg Attenuated Validation Loss: 22.8619
# Validation Loss for Scheduler: 2.1868
# saving model
# Epoch [73/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.5120
# Validation: Avg Standard Validation Loss: 2.1735
# Validation: Avg Attenuated Validation Loss: 23.5899
# Validation Loss for Scheduler: 2.1735
# saving model
# Epoch [74/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.1519
# Validation: Avg Standard Validation Loss: 2.1982
# Validation: Avg Attenuated Validation Loss: 22.5081
# Validation Loss for Scheduler: 2.1982
# saving model
# Epoch [75/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.0102
# Validation: Avg Standard Validation Loss: 2.1742
# Validation: Avg Attenuated Validation Loss: 23.2692
# Validation Loss for Scheduler: 2.1742
# saving model
# Epoch [76/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.4451
# Validation: Avg Standard Validation Loss: 2.1857
# Validation: Avg Attenuated Validation Loss: 23.6949
# Validation Loss for Scheduler: 2.1857
# saving model
# Epoch [77/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.3530
# Validation: Avg Standard Validation Loss: 2.1683
# Validation: Avg Attenuated Validation Loss: 23.6904
# Validation Loss for Scheduler: 2.1683
# saving model
# Epoch [78/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.0769
# Validation: Avg Standard Validation Loss: 2.1891
# Validation: Avg Attenuated Validation Loss: 22.9624
# Validation Loss for Scheduler: 2.1891
# saving model
# Epoch [79/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.0611
# Validation: Avg Standard Validation Loss: 2.1822
# Validation: Avg Attenuated Validation Loss: 22.6988
# Validation Loss for Scheduler: 2.1822
# saving model
# Epoch [80/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.7077888
# Training: Avg Attenuated Training Loss: 13.0745
# Validation: Avg Standard Validation Loss: 2.1733
# Validation: Avg Attenuated Validation Loss: 24.1656
# Validation Loss for Scheduler: 2.1733
# saving model
# Epoch [81/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.2420
# Validation: Avg Standard Validation Loss: 2.1793
# Validation: Avg Attenuated Validation Loss: 22.4141
# Validation Loss for Scheduler: 2.1793
# saving model
# Epoch [82/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.4216
# Validation: Avg Standard Validation Loss: 2.1614
# Validation: Avg Attenuated Validation Loss: 23.2893
# Validation Loss for Scheduler: 2.1614
# saving model
# Epoch [83/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.1028
# Validation: Avg Standard Validation Loss: 2.1667
# Validation: Avg Attenuated Validation Loss: 22.1596
# Validation Loss for Scheduler: 2.1667
# saving model
# Epoch [84/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.3565
# Validation: Avg Standard Validation Loss: 2.1731
# Validation: Avg Attenuated Validation Loss: 22.7522
# Validation Loss for Scheduler: 2.1731
# saving model
# Epoch [85/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.2261
# Validation: Avg Standard Validation Loss: 2.1569
# Validation: Avg Attenuated Validation Loss: 20.2374
# Validation Loss for Scheduler: 2.1569
# saving model
# Epoch [86/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.0852
# Validation: Avg Standard Validation Loss: 2.1633
# Validation: Avg Attenuated Validation Loss: 22.6455
# Validation Loss for Scheduler: 2.1633
# saving model
# Epoch [87/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.5626
# Validation: Avg Standard Validation Loss: 2.1665
# Validation: Avg Attenuated Validation Loss: 23.0262
# Validation Loss for Scheduler: 2.1665
# saving model
# Epoch [88/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.1029
# Validation: Avg Standard Validation Loss: 2.1759
# Validation: Avg Attenuated Validation Loss: 24.2865
# Validation Loss for Scheduler: 2.1759
# saving model
# Epoch [89/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.4549
# Validation: Avg Standard Validation Loss: 2.1496
# Validation: Avg Attenuated Validation Loss: 23.2618
# Validation Loss for Scheduler: 2.1496
# saving model
# Epoch [90/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.2662
# Validation: Avg Standard Validation Loss: 2.1770
# Validation: Avg Attenuated Validation Loss: 21.8892
# Validation Loss for Scheduler: 2.1770
# saving model
# Epoch [91/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.3181
# Validation: Avg Standard Validation Loss: 2.1805
# Validation: Avg Attenuated Validation Loss: 22.2490
# Validation Loss for Scheduler: 2.1805
# saving model
# Epoch [92/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.2150
# Validation: Avg Standard Validation Loss: 2.1550
# Validation: Avg Attenuated Validation Loss: 23.3230
# Validation Loss for Scheduler: 2.1550
# saving model
# Epoch [93/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.0874
# Validation: Avg Standard Validation Loss: 2.1821
# Validation: Avg Attenuated Validation Loss: 23.4262
# Validation Loss for Scheduler: 2.1821
# saving model
# Epoch [94/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.2528
# Validation: Avg Standard Validation Loss: 2.1685
# Validation: Avg Attenuated Validation Loss: 25.7769
# Validation Loss for Scheduler: 2.1685
# saving model
# Epoch [95/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.2471
# Validation: Avg Standard Validation Loss: 2.1691
# Validation: Avg Attenuated Validation Loss: 24.2641
# Validation Loss for Scheduler: 2.1691
# saving model
# Epoch [96/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.4285
# Validation: Avg Standard Validation Loss: 2.1670
# Validation: Avg Attenuated Validation Loss: 21.7407
# Validation Loss for Scheduler: 2.1670
# saving model
# Epoch [97/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.2744
# Validation: Avg Standard Validation Loss: 2.1736
# Validation: Avg Attenuated Validation Loss: 23.4847
# Validation Loss for Scheduler: 2.1736
# saving model
# Epoch [98/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.4386
# Validation: Avg Standard Validation Loss: 2.1721
# Validation: Avg Attenuated Validation Loss: 22.3046
# Validation Loss for Scheduler: 2.1721
# saving model
# Epoch [99/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.0973
# Validation: Avg Standard Validation Loss: 2.1602
# Validation: Avg Attenuated Validation Loss: 22.2432
# Validation Loss for Scheduler: 2.1602
# saving model
# Epoch [100/100], Learning Rate: 1e-09, Teacher forcing ratio: 0.679477248
# Training: Avg Attenuated Training Loss: 13.0958
# Validation: Avg Standard Validation Loss: 2.1725
# Validation: Avg Attenuated Validation Loss: 22.6427
# Validation Loss for Scheduler: 2.1725
# saving model
# Training complete.
# Model saved to path: repair_shop_full_grad_norm_new_4layer.pkl

# %% [markdown]
# # Training Visualization

# %%
import matplotlib.pyplot as plt

# After training is finished, plot the loss curves
plt.plot(range(1, num_epochs+1), train_attenuated_losses, label='Training Attenuated Loss', color='blue')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss', color='orange')
plt.plot(range(1, num_epochs+1), val_attenuated_losses, label='Validation Attenuated Loss', color='green')
# Labeling x and y axes
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
# Adding title
plt.title('Training and Validation Loss Curve', fontsize=14)
# Adding legend
plt.legend()
# Show the plot
plt.show()
