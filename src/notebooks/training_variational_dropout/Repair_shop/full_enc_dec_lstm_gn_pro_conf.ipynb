# %% [markdown]
# # Imports

# %%
import importlib
import sys

import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["TORCH_NUM_THREADS"] = "1"

import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../ProbabilisticSuffixPredictionLab/risk_controlled_proactive_conformance_checking_dev/data/encoded_data/Repair/Repair_all_normal_3_train.pkl'
# Load the dataset using torch.load
repair_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(repair_train_dataset))

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../ProbabilisticSuffixPredictionLab/risk_controlled_proactive_conformance_checking_dev/data/encoded_data/Repair/Repair_all_normal_3_val.pkl'
# Load the dataset using torch.load
repair_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(repair_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Repair Dataset Categories, Features:
repair_all_categories = repair_train_dataset.all_categories

repair_all_categories_cat = repair_all_categories[0]
print(repair_all_categories_cat)

repair_all_categories_num = repair_all_categories[1]
print(repair_all_categories_num)

for i, cat in enumerate(repair_all_categories_cat):
     print(f"Repair (3) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Repair (3) Total Amount of Category labels: {cat[1]}")
print('\n')    
for i, num in enumerate(repair_all_categories_num):
     print(f"Repair (3) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Repair (3) Amount Category Lables: {num[1]}")
# Out:
# [('concept:name', 9, {'ACKNOWLEDGEMENT': 1, 'CREATE_INVOICE': 2, 'DISASSEMBLY': 3, 'EOS': 4, 'QUALITY_CONTROL': 5, 'RECEPTION': 6, 'REPAIR': 7, 'SHIPPING': 8}), ('org:resource', 52, {'0.0': 1, '1.0': 2, '10.0': 3, '11.0': 4, '12.0': 5, '13.0': 6, '14.0': 7, '15.0': 8, '16.0': 9, '17.0': 10, '18.0': 11, '19.0': 12, '2.0': 13, '20.0': 14, '21.0': 15, '22.0': 16, '23.0': 17, '24.0': 18, '25.0': 19, '26.0': 20, '27.0': 21, '28.0': 22, '29.0': 23, '3.0': 24, '30.0': 25, '31.0': 26, '32.0': 27, '33.0': 28, '34.0': 29, '35.0': 30, '36.0': 31, '37.0': 32, '38.0': 33, '39.0': 34, '4.0': 35, '40.0': 36, '41.0': 37, '42.0': 38, '43.0': 39, '44.0': 40, '45.0': 41, '46.0': 42, '47.0': 43, '48.0': 44, '49.0': 45, '5.0': 46, '6.0': 47, '7.0': 48, '8.0': 49, '9.0': 50, nan: 51})]
# [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})]
# Repair (3) Categorical feature: concept:name, Index position in categorical data list: 0
# Repair (3) Total Amount of Category labels: 9
# Repair (3) Categorical feature: org:resource, Index position in categorical data list: 1
# Repair (3) Total Amount of Category labels: 52
#
#
# Repair (3) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Repair (3) Amount Category Lables: 1
# Repair (3) Numerical feature: event_elapsed_time, Index position in categorical data list: 1
# Repair (3) Amount Category Lables: 1
# Repair (3) Numerical feature: day_in_week, Index position in categorical data list: 2
# Repair (3) Amount Category Lables: 1
# Repair (3) Numerical feature: seconds_in_day, Index position in categorical data list: 3
# Repair (3) Amount Category Lables: 1

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Encoder features (input) and decoder features (input & output)

# Encoder features:
enc_feat_cat = []
enc_feat_num = []
for cat in repair_all_categories_cat:
    enc_feat_cat.append(cat[0])
for num in repair_all_categories_num:
    enc_feat_num.append(num[0])
enc_feat = [enc_feat_cat, enc_feat_num]
print("Input features encoder: ", enc_feat)

"""
# Decoder features:
dec_feat_cat = enc_feat_cat
dec_feat_num = enc_feat_num
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
"""

# Decoder features:
dec_feat_cat = ['concept:name']
# dec_feat_num = ['case_elapsed_time', 'event_elapsed_time']
dec_feat_num = ['case_elapsed_time']
dec_feat = [dec_feat_cat, dec_feat_num]
print("Features decoder: ", dec_feat)
# Out:
# Input features encoder:  [['concept:name', 'org:resource'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Features decoder:  [['concept:name'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model
importlib.reload(model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model)
from model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

# Prediction decoder output sequence length
# seq_len_pred = 4
seq_len_pred = 2

# Size hidden layer
hidden_size = 128

# Number of cells
num_layers = 4

# Fixed Dropout probability 
dropout = 0.1

# Encoder Decoder model initialization
model = DropoutUncertaintyEncoderDecoderLSTM(data_set_categories=repair_all_categories,
                                             enc_feat=enc_feat,
                                             dec_feat=dec_feat,
                                             seq_len_pred=seq_len_pred,
                                             hidden_size=hidden_size,
                                             num_layers=num_layers,
                                             dropout=dropout)
# Out:
# Data set categories:  ([('concept:name', 9, {'ACKNOWLEDGEMENT': 1, 'CREATE_INVOICE': 2, 'DISASSEMBLY': 3, 'EOS': 4, 'QUALITY_CONTROL': 5, 'RECEPTION': 6, 'REPAIR': 7, 'SHIPPING': 8}), ('org:resource', 52, {'0.0': 1, '1.0': 2, '10.0': 3, '11.0': 4, '12.0': 5, '13.0': 6, '14.0': 7, '15.0': 8, '16.0': 9, '17.0': 10, '18.0': 11, '19.0': 12, '2.0': 13, '20.0': 14, '21.0': 15, '22.0': 16, '23.0': 17, '24.0': 18, '25.0': 19, '26.0': 20, '27.0': 21, '28.0': 22, '29.0': 23, '3.0': 24, '30.0': 25, '31.0': 26, '32.0': 27, '33.0': 28, '34.0': 29, '35.0': 30, '36.0': 31, '37.0': 32, '38.0': 33, '39.0': 34, '4.0': 35, '40.0': 36, '41.0': 37, '42.0': 38, '43.0': 39, '44.0': 40, '45.0': 41, '46.0': 42, '47.0': 43, '48.0': 44, '49.0': 45, '5.0': 46, '6.0': 47, '7.0': 48, '8.0': 49, '9.0': 50, nan: 51})], [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})])
# Encoder input features:  [['concept:name', 'org:resource'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Decoder input+output features:  [['concept:name'], ['case_elapsed_time']]
#
#
# Sequence length of decoder output:  2
#
#
# Cells hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.1
#
#
# Encoder number of labels for each input feature (categorical, numerical):  [[9, 52], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input:  [[0, 1], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(9, 5)
#   (1): Embedding(52, 15)
# )
# Total embedding feature size encoder:  20
# Total numerical feature size encoder:  4
# Input feature size encoder:  24
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [9]
# Decoder label values size for each numerical input feature:  [1]
# Decoder indices of tensors in dataset used as input:  [[0], [0]]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(9, 5)
# )
# Total embedding feature size decoder:  5
# Total numerical feature size decoder:  1
# Input feature size decoder:  6
# Output feature list of dicts (featue name, feature output size) of decoder:  [{'concept:name': 9}, {'case_elapsed_time': 1}]
# Decoder initialized!

# %% [markdown]
# # Loss Object Creation

# %%
import loss.losses
importlib.reload(loss.losses)
from loss.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import trainer.trainer
importlib.reload(trainer.trainer)
from trainer.trainer import Trainer
from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_repair_grad_conf_check01_3")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Start learning rate
learning_rate = 1e-5

# Optimizer and Scheduler
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, min_lr=1e-10)

# Epochs
num_epochs = 100

# Batch size
batch_size = 128

# lambda for L2 (weight, bias, dropout) regularization: According to formula: 1/2N
# regularization_term = 1.0/(2.0*batch_size)
regularization_term = 1e-4

# shuffle data
shuffle = True

# Teacher forcing: Smaller 0.5 more target events are used for next event prediction.
teacher_forcing_ratio = 0.75

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle,
                   "teacher_forcing_ratio":teacher_forcing_ratio,}

suffix_data_split_value = seq_len_pred

# GradNorm parameter
use_gradnorm = True
gn_alpha = 1.5
gn_learning_rate = 1e-4

number_tasks = len(dec_feat[0]) + len(dec_feat[1])

gradNorm = {"use_gradnorm":use_gradnorm,
            "number_tasks": number_tasks,
            "gn_alpha":gn_alpha,
            "gn_learning_rate": gn_learning_rate}

trainer = Trainer(device=device,
                  model=model,
                  data_train=repair_train_dataset,
                  data_val=repair_val_dataset,
                  loss_obj=loss_obj,
                  log_normal_loss_num_feature= [],
                  optimize_values=optimize_values,
                  suffix_data_split_value=suffix_data_split_value,
                  writer=writer,
                  gradnorm_values=gradNorm,
                  save_model_n_th_epoch = 1,
                  saving_path = 'Repair_full_grad_norm_proactive_conf_check_01_3.pkl')

# Train the model:
train_attenuated_losses, val_losses, val_attenuated_losses = trainer.train_model()
# Out:
# Device:  cuda
# Model:  DropoutUncertaintyEncoderDecoderLSTM(
#   (embeddings_enc): ModuleList(
#     (0): Embedding(9, 5)
#     (1): Embedding(52, 15)
#   )
#   (encoder): DropoutUncertaintyLSTMEncoder(
#     (embeddings): ModuleList(
#       (0): Embedding(9, 5)
#       (1): Embedding(52, 15)
#     )
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=24, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=24, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=24, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=24, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#   )
#   (embeddings_dec): ModuleList(
#     (0): Embedding(9, 5)
#   )
#   (decoder): DropoutUncertaintyLSTMDecoder(
#     (embeddings): ModuleList(
#       (0): Embedding(9, 5)
#     )
#     (first_layer): DropoutUncertaintyLSTMCell(
#       (Wi): Linear(in_features=6, out_features=128, bias=True)
#       (Ui): Linear(in_features=128, out_features=128, bias=True)
#       (Wf): Linear(in_features=6, out_features=128, bias=True)
#       (Uf): Linear(in_features=128, out_features=128, bias=True)
#       (Wc): Linear(in_features=6, out_features=128, bias=True)
#       (Uc): Linear(in_features=128, out_features=128, bias=True)
#       (Wo): Linear(in_features=6, out_features=128, bias=True)
#       (Uo): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (hidden_layers): ModuleList(
#       (0-2): 3 x DropoutUncertaintyLSTMCell(
#         (Wi): Linear(in_features=128, out_features=128, bias=True)
#         (Ui): Linear(in_features=128, out_features=128, bias=True)
#         (Wf): Linear(in_features=128, out_features=128, bias=True)
#         (Uf): Linear(in_features=128, out_features=128, bias=True)
#         (Wc): Linear(in_features=128, out_features=128, bias=True)
#         (Uc): Linear(in_features=128, out_features=128, bias=True)
#         (Wo): Linear(in_features=128, out_features=128, bias=True)
#         (Uo): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (output_layers): ModuleDict(
#       (concept:name_mean): Linear(in_features=128, out_features=9, bias=True)
#       (concept:name_var): Linear(in_features=128, out_features=9, bias=True)
#       (case_elapsed_time_mean): Linear(in_features=128, out_features=1, bias=True)
#       (case_elapsed_time_var): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# Train Dataset:  <event_log_loader.new_event_log_loader.EventLogDataset object at 0x7f6cffd127e0>
# Validation Dataset:  <event_log_loader.new_event_log_loader.EventLogDataset object at 0x7f6cf564ef90>
# Loss object for method calling:  <loss.losses.Loss object at 0x7f6cffd0b530>
# Num. feautures that follow log-normal PDF:  []
# regularization:  0.0001
# Optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f6cf3c5c380>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
# Teacher forcing ratio:  0.75
# Use GradNorm:  True
# GradNorm alpha:  1.5
# GradNorm learning rate:  0.0001
# Initial GradNorm loss weights:  Parameter containing:
# tensor([1., 1.], requires_grad=True)
# Initial loss values:  None
# GradNorm optimizer:  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.01
# )
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch [1/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 3.3796
# Validation: Avg Standard Validation Loss: 3.1039
# Validation: Avg Attenuated Validation Loss: 3.0400
# Validation Loss for Scheduler: 3.1039
# saving model
# Epoch [2/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 3.1445
# Validation: Avg Standard Validation Loss: 2.8148
# Validation: Avg Attenuated Validation Loss: 2.4842
# Validation Loss for Scheduler: 2.8148
# saving model
# Epoch [3/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 2.5377
# Validation: Avg Standard Validation Loss: 2.4627
# Validation: Avg Attenuated Validation Loss: 2.0795
# Validation Loss for Scheduler: 2.4627
# saving model
# Epoch [4/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 2.2128
# Validation: Avg Standard Validation Loss: 2.2859
# Validation: Avg Attenuated Validation Loss: 1.8701
# Validation Loss for Scheduler: 2.2859
# saving model
# Epoch [5/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 2.0737
# Validation: Avg Standard Validation Loss: 2.1249
# Validation: Avg Attenuated Validation Loss: 1.7082
# Validation Loss for Scheduler: 2.1249
# saving model
# Epoch [6/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 1.9104
# Validation: Avg Standard Validation Loss: 1.9752
# Validation: Avg Attenuated Validation Loss: 1.5404
# Validation Loss for Scheduler: 1.9752
# saving model
# Epoch [7/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 1.7692
# Validation: Avg Standard Validation Loss: 1.8524
# Validation: Avg Attenuated Validation Loss: 1.4118
# Validation Loss for Scheduler: 1.8524
# saving model
# Epoch [8/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 1.6481
# Validation: Avg Standard Validation Loss: 1.7391
# Validation: Avg Attenuated Validation Loss: 1.2730
# Validation Loss for Scheduler: 1.7391
# saving model
# Epoch [9/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 1.5085
# Validation: Avg Standard Validation Loss: 1.6376
# Validation: Avg Attenuated Validation Loss: 1.1727
# Validation Loss for Scheduler: 1.6376
# saving model
# Epoch [10/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 1.3583
# Validation: Avg Standard Validation Loss: 1.5415
# Validation: Avg Attenuated Validation Loss: 1.0625
# Validation Loss for Scheduler: 1.5415
# saving model
# Epoch [11/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 1.2229
# Validation: Avg Standard Validation Loss: 1.4437
# Validation: Avg Attenuated Validation Loss: 0.9009
# Validation Loss for Scheduler: 1.4437
# saving model
# Epoch [12/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 1.1101
# Validation: Avg Standard Validation Loss: 1.3774
# Validation: Avg Attenuated Validation Loss: 0.8497
# Validation Loss for Scheduler: 1.3774
# saving model
# Epoch [13/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 0.9902
# Validation: Avg Standard Validation Loss: 1.3202
# Validation: Avg Attenuated Validation Loss: 0.7930
# Validation Loss for Scheduler: 1.3202
# saving model
# Epoch [14/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 0.9096
# Validation: Avg Standard Validation Loss: 1.2718
# Validation: Avg Attenuated Validation Loss: 0.7576
# Validation Loss for Scheduler: 1.2718
# saving model
# Epoch [15/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 0.8729
# Validation: Avg Standard Validation Loss: 1.2436
# Validation: Avg Attenuated Validation Loss: 0.8586
# Validation Loss for Scheduler: 1.2436
# saving model
# Epoch [16/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 0.8471
# Validation: Avg Standard Validation Loss: 1.2065
# Validation: Avg Attenuated Validation Loss: 0.7132
# Validation Loss for Scheduler: 1.2065
# saving model
# Epoch [17/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 0.8243
# Validation: Avg Standard Validation Loss: 1.1976
# Validation: Avg Attenuated Validation Loss: 0.8542
# Validation Loss for Scheduler: 1.1976
# saving model
# Epoch [18/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 0.9055
# Validation: Avg Standard Validation Loss: 1.1833
# Validation: Avg Attenuated Validation Loss: 0.9721
# Validation Loss for Scheduler: 1.1833
# saving model
# Epoch [19/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 0.8982
# Validation: Avg Standard Validation Loss: 1.1716
# Validation: Avg Attenuated Validation Loss: 0.9817
# Validation Loss for Scheduler: 1.1716
# saving model
# Epoch [20/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.75
# Training: Avg Attenuated Training Loss: 0.8723
# Validation: Avg Standard Validation Loss: 1.1674
# Validation: Avg Attenuated Validation Loss: 1.1430
# Validation Loss for Scheduler: 1.1674
# saving model
# Epoch [21/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.8695
# Validation: Avg Standard Validation Loss: 1.1499
# Validation: Avg Attenuated Validation Loss: 0.7340
# Validation Loss for Scheduler: 1.1499
# saving model
# Epoch [22/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.8313
# Validation: Avg Standard Validation Loss: 1.1474
# Validation: Avg Attenuated Validation Loss: 1.2045
# Validation Loss for Scheduler: 1.1474
# saving model
# Epoch [23/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.8521
# Validation: Avg Standard Validation Loss: 1.1254
# Validation: Avg Attenuated Validation Loss: 0.8475
# Validation Loss for Scheduler: 1.1254
# saving model
# Epoch [24/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.7901
# Validation: Avg Standard Validation Loss: 1.1052
# Validation: Avg Attenuated Validation Loss: 0.8969
# Validation Loss for Scheduler: 1.1052
# saving model
# Epoch [25/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.8041
# Validation: Avg Standard Validation Loss: 1.0942
# Validation: Avg Attenuated Validation Loss: 0.9001
# Validation Loss for Scheduler: 1.0942
# saving model
# Epoch [26/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.7959
# Validation: Avg Standard Validation Loss: 1.0862
# Validation: Avg Attenuated Validation Loss: 0.8726
# Validation Loss for Scheduler: 1.0862
# saving model
# Epoch [27/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.8360
# Validation: Avg Standard Validation Loss: 1.0765
# Validation: Avg Attenuated Validation Loss: 1.0880
# Validation Loss for Scheduler: 1.0765
# saving model
# Epoch [28/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.7380
# Validation: Avg Standard Validation Loss: 1.0637
# Validation: Avg Attenuated Validation Loss: 0.9798
# Validation Loss for Scheduler: 1.0637
# saving model
# Epoch [29/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.7897
# Validation: Avg Standard Validation Loss: 1.0549
# Validation: Avg Attenuated Validation Loss: 0.7338
# Validation Loss for Scheduler: 1.0549
# saving model
# Epoch [30/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.7700
# Validation: Avg Standard Validation Loss: 1.0492
# Validation: Avg Attenuated Validation Loss: 0.9647
# Validation Loss for Scheduler: 1.0492
# saving model
# Epoch [31/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.7274
# Validation: Avg Standard Validation Loss: 1.0376
# Validation: Avg Attenuated Validation Loss: 0.8837
# Validation Loss for Scheduler: 1.0376
# saving model
# Epoch [32/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.7007
# Validation: Avg Standard Validation Loss: 1.0278
# Validation: Avg Attenuated Validation Loss: 0.8359
# Validation Loss for Scheduler: 1.0278
# saving model
# Epoch [33/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.6347
# Validation: Avg Standard Validation Loss: 1.0238
# Validation: Avg Attenuated Validation Loss: 0.7175
# Validation Loss for Scheduler: 1.0238
# saving model
# Epoch [34/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.7098
# Validation: Avg Standard Validation Loss: 1.0152
# Validation: Avg Attenuated Validation Loss: 0.9621
# Validation Loss for Scheduler: 1.0152
# saving model
# Epoch [35/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.6790
# Validation: Avg Standard Validation Loss: 1.0034
# Validation: Avg Attenuated Validation Loss: 0.8210
# Validation Loss for Scheduler: 1.0034
# saving model
# Epoch [36/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.6143
# Validation: Avg Standard Validation Loss: 1.0017
# Validation: Avg Attenuated Validation Loss: 0.9166
# Validation Loss for Scheduler: 1.0017
# saving model
# Epoch [37/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.6755
# Validation: Avg Standard Validation Loss: 0.9899
# Validation: Avg Attenuated Validation Loss: 0.7543
# Validation Loss for Scheduler: 0.9899
# saving model
# Epoch [38/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.6617
# Validation: Avg Standard Validation Loss: 0.9784
# Validation: Avg Attenuated Validation Loss: 0.8022
# Validation Loss for Scheduler: 0.9784
# saving model
# Epoch [39/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.5843
# Validation: Avg Standard Validation Loss: 0.9757
# Validation: Avg Attenuated Validation Loss: 0.7831
# Validation Loss for Scheduler: 0.9757
# saving model
# Epoch [40/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.675
# Training: Avg Attenuated Training Loss: 0.5965
# Validation: Avg Standard Validation Loss: 0.9683
# Validation: Avg Attenuated Validation Loss: 0.8688
# Validation Loss for Scheduler: 0.9683
# saving model
# Epoch [41/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.6707
# Validation: Avg Standard Validation Loss: 0.9624
# Validation: Avg Attenuated Validation Loss: 0.8042
# Validation Loss for Scheduler: 0.9624
# saving model
# Epoch [42/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.7299
# Validation: Avg Standard Validation Loss: 0.9529
# Validation: Avg Attenuated Validation Loss: 0.7508
# Validation Loss for Scheduler: 0.9529
# saving model
# Epoch [43/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.6077
# Validation: Avg Standard Validation Loss: 0.9436
# Validation: Avg Attenuated Validation Loss: 0.8148
# Validation Loss for Scheduler: 0.9436
# saving model
# Epoch [44/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.6180
# Validation: Avg Standard Validation Loss: 0.9368
# Validation: Avg Attenuated Validation Loss: 0.7470
# Validation Loss for Scheduler: 0.9368
# saving model
# Epoch [45/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.6620
# Validation: Avg Standard Validation Loss: 0.9300
# Validation: Avg Attenuated Validation Loss: 0.7847
# Validation Loss for Scheduler: 0.9300
# saving model
# Epoch [46/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.6649
# Validation: Avg Standard Validation Loss: 0.9272
# Validation: Avg Attenuated Validation Loss: 0.6605
# Validation Loss for Scheduler: 0.9272
# saving model
# Epoch [47/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5991
# Validation: Avg Standard Validation Loss: 0.9228
# Validation: Avg Attenuated Validation Loss: 0.8489
# Validation Loss for Scheduler: 0.9228
# saving model
# Epoch [48/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5278
# Validation: Avg Standard Validation Loss: 0.9145
# Validation: Avg Attenuated Validation Loss: 0.7133
# Validation Loss for Scheduler: 0.9145
# saving model
# Epoch [49/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5809
# Validation: Avg Standard Validation Loss: 0.9101
# Validation: Avg Attenuated Validation Loss: 0.7132
# Validation Loss for Scheduler: 0.9101
# saving model
# Epoch [50/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5818
# Validation: Avg Standard Validation Loss: 0.9050
# Validation: Avg Attenuated Validation Loss: 0.6554
# Validation Loss for Scheduler: 0.9050
# saving model
# Epoch [51/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5935
# Validation: Avg Standard Validation Loss: 0.9021
# Validation: Avg Attenuated Validation Loss: 0.8084
# Validation Loss for Scheduler: 0.9021
# saving model
# Epoch [52/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5578
# Validation: Avg Standard Validation Loss: 0.8960
# Validation: Avg Attenuated Validation Loss: 0.8065
# Validation Loss for Scheduler: 0.8960
# saving model
# Epoch [53/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5204
# Validation: Avg Standard Validation Loss: 0.8916
# Validation: Avg Attenuated Validation Loss: 0.8526
# Validation Loss for Scheduler: 0.8916
# saving model
# Epoch [54/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.6306
# Validation: Avg Standard Validation Loss: 0.8868
# Validation: Avg Attenuated Validation Loss: 0.8083
# Validation Loss for Scheduler: 0.8868
# saving model
# Epoch [55/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.6145
# Validation: Avg Standard Validation Loss: 0.8877
# Validation: Avg Attenuated Validation Loss: 0.8547
# Validation Loss for Scheduler: 0.8877
# saving model
# Epoch [56/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5838
# Validation: Avg Standard Validation Loss: 0.8806
# Validation: Avg Attenuated Validation Loss: 0.7579
# Validation Loss for Scheduler: 0.8806
# saving model
# Epoch [57/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5838
# Validation: Avg Standard Validation Loss: 0.8741
# Validation: Avg Attenuated Validation Loss: 0.6932
# Validation Loss for Scheduler: 0.8741
# saving model
# Epoch [58/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5274
# Validation: Avg Standard Validation Loss: 0.8762
# Validation: Avg Attenuated Validation Loss: 0.7980
# Validation Loss for Scheduler: 0.8762
# saving model
# Epoch [59/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.5688
# Validation: Avg Standard Validation Loss: 0.8713
# Validation: Avg Attenuated Validation Loss: 0.8119
# Validation Loss for Scheduler: 0.8713
# saving model
# Epoch [60/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.6075
# Training: Avg Attenuated Training Loss: 0.6241
# Validation: Avg Standard Validation Loss: 0.8735
# Validation: Avg Attenuated Validation Loss: 1.0268
# Validation Loss for Scheduler: 0.8735
# saving model
# Epoch [61/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.5809
# Validation: Avg Standard Validation Loss: 0.8616
# Validation: Avg Attenuated Validation Loss: 0.7594
# Validation Loss for Scheduler: 0.8616
# saving model
# Epoch [62/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.5692
# Validation: Avg Standard Validation Loss: 0.8591
# Validation: Avg Attenuated Validation Loss: 0.9819
# Validation Loss for Scheduler: 0.8591
# saving model
# Epoch [63/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.5959
# Validation: Avg Standard Validation Loss: 0.8527
# Validation: Avg Attenuated Validation Loss: 0.7596
# Validation Loss for Scheduler: 0.8527
# saving model
# Epoch [64/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6950
# Validation: Avg Standard Validation Loss: 0.8497
# Validation: Avg Attenuated Validation Loss: 0.7656
# Validation Loss for Scheduler: 0.8497
# saving model
# Epoch [65/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6447
# Validation: Avg Standard Validation Loss: 0.8469
# Validation: Avg Attenuated Validation Loss: 0.8495
# Validation Loss for Scheduler: 0.8469
# saving model
# Epoch [66/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6708
# Validation: Avg Standard Validation Loss: 0.8451
# Validation: Avg Attenuated Validation Loss: 0.7912
# Validation Loss for Scheduler: 0.8451
# saving model
# Epoch [67/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6574
# Validation: Avg Standard Validation Loss: 0.8459
# Validation: Avg Attenuated Validation Loss: 0.9178
# Validation Loss for Scheduler: 0.8459
# saving model
# Epoch [68/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6675
# Validation: Avg Standard Validation Loss: 0.8443
# Validation: Avg Attenuated Validation Loss: 1.0154
# Validation Loss for Scheduler: 0.8443
# saving model
# Epoch [69/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6667
# Validation: Avg Standard Validation Loss: 0.8410
# Validation: Avg Attenuated Validation Loss: 0.9617
# Validation Loss for Scheduler: 0.8410
# saving model
# Epoch [70/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6166
# Validation: Avg Standard Validation Loss: 0.8352
# Validation: Avg Attenuated Validation Loss: 0.9861
# Validation Loss for Scheduler: 0.8352
# saving model
# Epoch [71/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6914
# Validation: Avg Standard Validation Loss: 0.8291
# Validation: Avg Attenuated Validation Loss: 1.0152
# Validation Loss for Scheduler: 0.8291
# saving model
# Epoch [72/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6370
# Validation: Avg Standard Validation Loss: 0.8277
# Validation: Avg Attenuated Validation Loss: 0.8716
# Validation Loss for Scheduler: 0.8277
# saving model
# Epoch [73/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6789
# Validation: Avg Standard Validation Loss: 0.8249
# Validation: Avg Attenuated Validation Loss: 0.7809
# Validation Loss for Scheduler: 0.8249
# saving model
# Epoch [74/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.7479
# Validation: Avg Standard Validation Loss: 0.8239
# Validation: Avg Attenuated Validation Loss: 0.8288
# Validation Loss for Scheduler: 0.8239
# saving model
# Epoch [75/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6765
# Validation: Avg Standard Validation Loss: 0.8166
# Validation: Avg Attenuated Validation Loss: 0.9395
# Validation Loss for Scheduler: 0.8166
# saving model
# Epoch [76/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.7290
# Validation: Avg Standard Validation Loss: 0.8193
# Validation: Avg Attenuated Validation Loss: 0.7655
# Validation Loss for Scheduler: 0.8193
# saving model
# Epoch [77/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.6487
# Validation: Avg Standard Validation Loss: 0.8143
# Validation: Avg Attenuated Validation Loss: 0.7705
# Validation Loss for Scheduler: 0.8143
# saving model
# Epoch [78/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.7351
# Validation: Avg Standard Validation Loss: 0.8124
# Validation: Avg Attenuated Validation Loss: 1.0284
# Validation Loss for Scheduler: 0.8124
# saving model
# Epoch [79/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.7379
# Validation: Avg Standard Validation Loss: 0.8110
# Validation: Avg Attenuated Validation Loss: 0.8695
# Validation Loss for Scheduler: 0.8110
# saving model
# Epoch [80/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.5467500000000001
# Training: Avg Attenuated Training Loss: 0.7038
# Validation: Avg Standard Validation Loss: 0.8110
# Validation: Avg Attenuated Validation Loss: 0.9062
# Validation Loss for Scheduler: 0.8110
# saving model
# Epoch [81/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.8141
# Validation: Avg Standard Validation Loss: 0.8081
# Validation: Avg Attenuated Validation Loss: 1.0187
# Validation Loss for Scheduler: 0.8081
# saving model
# Epoch [82/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.7233
# Validation: Avg Standard Validation Loss: 0.8053
# Validation: Avg Attenuated Validation Loss: 0.8815
# Validation Loss for Scheduler: 0.8053
# saving model
# Epoch [83/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.7781
# Validation: Avg Standard Validation Loss: 0.8002
# Validation: Avg Attenuated Validation Loss: 0.8846
# Validation Loss for Scheduler: 0.8002
# saving model
# Epoch [84/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.8712
# Validation: Avg Standard Validation Loss: 0.8031
# Validation: Avg Attenuated Validation Loss: 1.0186
# Validation Loss for Scheduler: 0.8031
# saving model
# Epoch [85/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.7984
# Validation: Avg Standard Validation Loss: 0.8025
# Validation: Avg Attenuated Validation Loss: 1.1278
# Validation Loss for Scheduler: 0.8025
# saving model
# Epoch [86/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 1.0688
# Validation: Avg Standard Validation Loss: 0.8006
# Validation: Avg Attenuated Validation Loss: 1.1935
# Validation Loss for Scheduler: 0.8006
# saving model
# Epoch [87/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 1.0935
# Validation: Avg Standard Validation Loss: 0.7979
# Validation: Avg Attenuated Validation Loss: 1.2052
# Validation Loss for Scheduler: 0.7979
# saving model
# Epoch [88/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 1.0373
# Validation: Avg Standard Validation Loss: 0.7920
# Validation: Avg Attenuated Validation Loss: 1.0514
# Validation Loss for Scheduler: 0.7920
# saving model
# Epoch [89/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.9629
# Validation: Avg Standard Validation Loss: 0.7916
# Validation: Avg Attenuated Validation Loss: 0.9510
# Validation Loss for Scheduler: 0.7916
# saving model
# Epoch [90/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.7374
# Validation: Avg Standard Validation Loss: 0.7906
# Validation: Avg Attenuated Validation Loss: 1.1170
# Validation Loss for Scheduler: 0.7906
# saving model
# Epoch [91/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.9087
# Validation: Avg Standard Validation Loss: 0.7892
# Validation: Avg Attenuated Validation Loss: 1.0991
# Validation Loss for Scheduler: 0.7892
# saving model
# Epoch [92/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.8654
# Validation: Avg Standard Validation Loss: 0.7882
# Validation: Avg Attenuated Validation Loss: 0.9617
# Validation Loss for Scheduler: 0.7882
# saving model
# Epoch [93/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.7585
# Validation: Avg Standard Validation Loss: 0.7864
# Validation: Avg Attenuated Validation Loss: 1.1018
# Validation Loss for Scheduler: 0.7864
# saving model
# Epoch [94/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.8282
# Validation: Avg Standard Validation Loss: 0.7888
# Validation: Avg Attenuated Validation Loss: 1.1682
# Validation Loss for Scheduler: 0.7888
# saving model
# Epoch [95/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.7890
# Validation: Avg Standard Validation Loss: 0.7839
# Validation: Avg Attenuated Validation Loss: 0.8886
# Validation Loss for Scheduler: 0.7839
# saving model
# Epoch [96/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.9336
# Validation: Avg Standard Validation Loss: 0.7812
# Validation: Avg Attenuated Validation Loss: 0.9684
# Validation Loss for Scheduler: 0.7812
# saving model
# Epoch [97/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.7908
# Validation: Avg Standard Validation Loss: 0.7773
# Validation: Avg Attenuated Validation Loss: 1.2106
# Validation Loss for Scheduler: 0.7773
# saving model
# Epoch [98/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.8783
# Validation: Avg Standard Validation Loss: 0.7821
# Validation: Avg Attenuated Validation Loss: 1.0867
# Validation Loss for Scheduler: 0.7821
# saving model
# Epoch [99/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.9199
# Validation: Avg Standard Validation Loss: 0.7774
# Validation: Avg Attenuated Validation Loss: 0.9920
# Validation Loss for Scheduler: 0.7774
# saving model
# Epoch [100/100], Learning Rate: 1e-05, Teacher forcing ratio: 0.49207500000000004
# Training: Avg Attenuated Training Loss: 0.9058
# Validation: Avg Standard Validation Loss: 0.7765
# Validation: Avg Attenuated Validation Loss: 0.8330
# Validation Loss for Scheduler: 0.7765
# saving model
# Training complete.
# Model saved to path: Repair_full_grad_norm_proactive_conf_check_01_3.pkl

# %% [markdown]
# # Training Visualization

# %%
import matplotlib.pyplot as plt

# After training is finished, plot the loss curves
plt.plot(range(1, num_epochs+1), train_attenuated_losses, label='Training Attenuated Loss', color='blue')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss', color='orange')
plt.plot(range(1, num_epochs+1), val_attenuated_losses, label='Validation Attenuated Loss', color='green')
# Labeling x and y axes
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
# Adding title
plt.title('Training and Validation Loss Curve', fontsize=14)
# Adding legend
plt.legend()
# Show the plot
plt.show()
