# %%
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../encoded_data/helpdesk_all_1_train.pkl'
# Load the dataset using torch.load
train_dataset = torch.load(file_path_train, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../encoded_data/helpdesk_all_1_val.pkl'
# Load the dataset using torch.load
val_dataset = torch.load(file_path_val, weights_only=False)

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../encoded_data/helpdesk_all_1_test.pkl'
# Load the dataset using torch.load
test_dataset = torch.load(file_path_val, weights_only=False)


test = 1

# %%
print(len(train_dataset.tensor_list[0]))
print(train_dataset.tensor_list[1][0].size())
print(len(train_dataset.tensor_list[2]))
# Out:
# 1
# torch.Size([16895, 10])
# 16895
